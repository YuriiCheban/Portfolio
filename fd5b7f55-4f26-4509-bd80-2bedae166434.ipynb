# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color = "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Юрий :)
#
# Спасибо за работу на проекте, за все исправления и комментарии
#
# Стоит завершить фильтрацию данных, стоит обращать внимание на минимальные и максимальные значения.  На этапе предобработки стоит использовать больше гистограмм, чтобы оценить качество данных
#
# Подведем итоги, мы научились и повторили на проекте каким образом:
#
# + читать тех. задание проекта
# + исследовать неочищенные данные
# + выдвигать гипотезы о пропусках данных и заполнять их значениями
# + принимать решения об удалении некачественных данных
# + находить аномалии в данных и отделять редкие значения
# + соглашаться с наличием пропусков в данных и не забывать об их наличии при фильтрации
# + строить информативные визуализации
# + делить одну выборку на две части
# + находить зависимости и распределения в данных
# + формировать выводы
#
# Навыки отработаны, проект принят
#
# <b>Поздравляю с успешно сданным третьим проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Привет, Юрий :) Спасибо за все исправления и комментарии
#
# Критические ❌ комментарии (все с красным фоном)
#
# + завершить фильтрацию редких значений в п. 2.4, оставил пример в бонусной части
# + ознакомиться с выводом в п.4.3 об изменении цен по годам
# + исследовать аномалии в п.4.5
# + поправить итоговый вывод
#
# добавил подсказки
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Привет, Юрий :) Спасибо за все исправления и комментарии
#
# Критические ❌ комментарии
#
# + принять решение после проверки корректности заполнения пропусков синтетическими данными
# + настроить фильтрацию редких значений в п. 2.4
# + добавить вывод в п. 4.3 об изменении цен по годам
# + исследовать аномалии в п.4.5
# + поправить итоговый вывод
#
# добавил подсказки и бонус
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Юрий :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# В обработке данных и заполнении синтетическими данными Сделал проверку, как ты говорил: 561 пропуск, Все таки аномалии есть. Не понимаю, как поступить. Не трогать этот столбец вообще?
#
# Пункт 2.4 Проекта, 2.5 check gap. Нужно обработать указанные тобой столбцы с аномалиями и избавиться от редких значений, или могу оставить как есть?
#
# В расчетах все поправил)
#
# По комментариям пунка 4.5 не совсем понял, что нужно поправить. Идея в том, что ранее мы заполниил пропуски заглушками, что бы округлить значения в столбце 'city_centers_nearest_km' и привести его к типу int. Далее мы делаем срез без этих значений (инфо по столбцу ниже). А дальше делаем сводник и строим гистограмму. + Поменял значения на 100 000 (решил поставить больше, что бы точно не было таких значений)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />да, нам нужно по каждому параметру построить по три гистограммы, как в примере с площадью и отрезать все редкости, аномлии и хвосты

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />оставлю примеры по месту

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название, краткое вступление в работу и главная задача зафиксированы.
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, + будет легче  идти к главной цели проекта

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('/datasets/real_estate_data.csv')
print(data.info())
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                           --------------  -----
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит делить блок загрузки библиотек и код загрузки датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %%
try:
    data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
    display(data.head())
except:
    print('Ошибка чтения файла')
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.hist(figsize=(15, 20));

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Убрать служ. информацию поможет точка с запятой на посл. строке кода
#
#     array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)
#
# data.hist(figsize=(15, 20));

# %% [markdown]
# # Выводы

# %% [markdown]
# Прочитали таблицу, проставили разделители, данные выгрузились корректно.
# По итогам вызова метода info() видно, что есть пропуски и неверные типы данных в столбцах.
# По гисторграммам видно, что есть аномалии.
# Пристумип к предобработке данных

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> обзор данных проведен корректно

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Обработка пропусков

# %%
data.isna().sum() # находим количество пропущенных значений по каждой строке
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Пропуски по столбцам:
# - ceiling_height - большое количество прпоусков. Для исследования данные по столбцу не нужны, можно пропустить.
# - floors_total - не значительное количество пропусков. Появлению прпоусков могли послужить не заполнение данных, одноэтажное сдание - просто не посчитали нужным заполнить, технические ошибки. Строки можно удалить, так как они влияют на тип данных в столбце.
# - living_area - порядка 8 % пропусков. Можно заполнить. Причины появления прпоусков могут быть разные: технические ошибки, не указали данные, или же это коммерческие помещения и т.д.
# - is_apartment - большое количество пропусков. Для целей исследования данные не нужны. Но из-за отсутствия данных нарушается тип стобца (bool). Заменим пропущенные значения на False, что бы в дальнейшем привести столбец к типу "bool"
# - kitchen_area - прпоусков не так много. Возможно прпоуски возникли, т.к. это сдуния, или кухня-гостинная. Оставим, как есть.
# - balcony - большое количество прпоусков. Нет данных - нет балконов. Заполним пропуски значением "0"
#
# Столбцы ниже имеют не маленькое количество прпоусков, но для исследования они не нужны, их мы обрабатывать не будем.
# - airports_nearest
# - parks_around3000
# - parks_nearest
# - ponds_around3000
# - ponds_nearest
# Причинами прпоусков в столбцах могут быть ошибки в данных, отсутствие парков, аэропортов и водоемов в пределах населенных пунктов и т.д.

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста

# %% [markdown]
# Удалим строки с пропущенными значениями в столбце floors_total и перезапишем индексы.

# %%
data = data.dropna(subset=['floors_total']).reset_index(drop=True)

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9118
# floors_total                0
# living_area              1870
# floor                       0
# is_apartment            20838
# studio                      0
# open_plan                   0
# kitchen_area             2231
# balcony                 11480
# locality_name              48
# airports_nearest         5532
# cityCenters_nearest      5509
# parks_around3000         5508
# parks_nearest           15568
# ponds_around3000         5508
# ponds_nearest           14552
# days_exposition          3172
# dtype: int64

# %% [markdown]
# заполним пропуски по столбцу "balcony" значениями "0"

# %%
data['balcony'] = data['balcony'].fillna(0)
# проверяем столбец на наличие пропусков.
data['balcony'].isna().sum()
# Out:
# 0

# %% [markdown]
# Проверим столбец с данными "living_area":

# %%
print('Количество прпоусков:', data['living_area'].isna().sum())
data['living_area'].describe()
# Out:
# Количество прпоусков: 1870
# count    21743.000000
# mean        34.462781
# std         22.037433
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# Странное минимальное значение - 2 м2. Минимальное и максимальное значения говорят о том, что для заполнения пропусков брать среднее значение будет не корректно (есть выбросы и аномальные значения). Можно заполнить пропуски медианным значением по категориям количества комнат.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />После заполнения синтетическими данными столбцов, стоит провести проверку на корректность значений всех наших площадей, т.к. есть (коридоры, сан.узлы, балконы)
#
#         total_area*0.9 <= (living_area + kitchen_area)
#
# если алгоритм приводит к появлению аномалий, стоит подумать над его содержимым

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='living_area' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'black', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — Жилая');

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Аномалии проявились на графике — стоит принять решение или изменить алгоритм заполнения пропусков, или оставить пропуски, или заполнить маркерами
#
# при изменении способа обработки колонок, стоит перепроверить код фильтрации
#
# __Самое важное — приобрести навык__ — любая замена пропусков очень трудоемка по ресурсам, т.к. приходится искать оптимальный вариант и если можно работать, имея пропуски в данных — лучше отказаться от заполнения
#
# но есть другие случаи, когда пропуски заполнять обязательно нужно, на проекте по стат. анализу — внимательно посмотри на пропуски в данных в объединенной таблице (кроме даты оттока клиентов)
#
# в итоге каждый раз мы вынуждены будем принимать решение — заполнять пропуски и как заполнять, или оставлять

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Принял решение оставить пропуски) Т.к. они составляют проядка 7% данных. И твой график особо не изменился. Еще думал о том, что можно было бы после заполнения в цикле проверить появления аномалий по твоей формуле и избавиться от значений, не соответствующих ей. Но думаю, что это не корректно.

# %% [markdown]
# Заполним пропущенные значения в столбце is_apartment значениями False

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %% [markdown]
# #### Типы данных в строках

# %% [markdown]
# Проверим информацию о  получившемся датафрейме.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23613 entries, 0 to 23612
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23613 non-null  int64
#  1   last_price            23613 non-null  float64
#  2   total_area            23613 non-null  float64
#  3   first_day_exposition  23613 non-null  object
#  4   rooms                 23613 non-null  int64
#  5   ceiling_height        14495 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21743 non-null  float64
#  8   floor                 23613 non-null  int64
#  9   is_apartment          23613 non-null  bool
#  10  studio                23613 non-null  bool
#  11  open_plan             23613 non-null  bool
#  12  kitchen_area          21382 non-null  float64
#  13  balcony               23613 non-null  float64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# Проблемы с типами данных в след. столбцах:
#
# - first_day_exposition - необходимо перевести в тип date. Так как в столбцах хранятся даты.
# - floors_total, balcony - переведем в "int", так как число балконов и количество этажей не могут быть дробными, там хранятся целые числа.
# - is_apartment  перешел в тип bool после того, как мы заполнили пропуски, как False.
# В остальном - все хорошо.

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
    
for i in  data[['floors_total', 'balcony', 'last_price']]:# приводим столбцы к  типу int
    data[i] = data[i].astype('int')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23613 entries, 0 to 23612
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23613 non-null  int64
#  1   last_price            23613 non-null  int64
#  2   total_area            23613 non-null  float64
#  3   first_day_exposition  23613 non-null  datetime64[ns]
#  4   rooms                 23613 non-null  int64
#  5   ceiling_height        14495 non-null  float64
#  6   floors_total          23613 non-null  int64
#  7   living_area           21743 non-null  float64
#  8   floor                 23613 non-null  int64
#  9   is_apartment          23613 non-null  bool
#  10  studio                23613 non-null  bool
#  11  open_plan             23613 non-null  bool
#  12  kitchen_area          21382 non-null  float64
#  13  balcony               23613 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# После повторной проверки видим, что типы встали, как надо.

# %% [markdown]
# #### Обработка уникальных значений

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# Приведем разновидности поселков к единому  наименованию -  поселок.

# %%
data['locality_name'] = data['locality_name'].replace(['посёлок',
                                                       'посёлок городского типа',
                                                       'поселок городского типа',
                                                       'городской посёлок',
                                                       'городской поселок',
                                                       'коттеджный посёлок',
                                                       'коттеджный поселок'], 'поселок', regex=True)
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'поселок Шушары', 'городской поселок Янино-1',
#        'поселок Парголово', 'поселок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок Красный Бор', 'Гатчина', 'деревня Фёдоровское', 'Выборг',
#        'Кронштадт', 'Кировск', 'деревня Новое Девяткино',
#        'поселок Металлострой', 'поселок городского типа Лебяжье',
#        'поселок городского типа Сиверский', 'поселок Молодцово',
#        'поселок Кузьмоловский', 'садовое товарищество Новая Ропша',
#        'Павловск', 'деревня Пикколово', 'Всеволожск', 'Волхов',
#        'Кингисепп', 'Приозерск', 'Сестрорецк', 'деревня Куттузи',
#        'поселок Аннино', 'поселок Ефимовский', 'поселок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
#        'Красное Село', 'поселок Понтонный', 'Сясьстрой', 'деревня Старая',
#        'деревня Лесколово', 'поселок Новый Свет', 'Сланцы',
# ...

# %%
# check
data.locality_name.nunique()
# Out:
# 338

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />хорошая работа по избавлению от неявных дубликатов

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# Для того, __чтобы изменить лишь часть строки,__ можно добавить к коду — .str
#
#         .str.replace('посёлок','поселок')
#
# [Метод str.replace() в Python, меняет подстроку/символ в строке](https://docs-python.ru/tutorial/operatsii-tekstovymi-strokami-str-python/metod-str-replace/)

# %% [markdown]
# #### Обработка аномалий

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23613.000000  2.361300e+04  23613.000000  23613.000000    14495.000000
# mean       9.874518  6.540555e+06     60.340678      2.071147        2.771495
# std        5.681541  1.090172e+07     35.648988      1.078380        1.261445
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.799000e+06     69.800000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21743.000000  23613.000000  21382.000000  23613.000000
# mean      10.673824     34.462781      5.877313     10.564128      0.593063
# ...

# %% [markdown]
# Видно, что есть выбивающиеся значения. Площадь, количество комнат, этажность еще можно обьяснить (Например элитная недвижимость). Потолков высотой 100 м точно  не может  быть, посмотрит на этот столбец, сделаем срез данных, где высота потолков больше 10 м.

# %%
data.query('ceiling_height > 10')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 353              17     3600000        55.2           2018-07-12      2
# 3138             14     2900000        75.0           2018-11-12      3
# 4628              0     4300000        45.0           2018-02-01      2
# 4860              7     3000000        25.0           2017-09-27      0
# 5059              0     3850000        30.5           2018-10-03      1
# 5227              0     2500000        54.0           2017-10-13      2
# 5650              4     4400000        50.0           2017-08-08      2
# 5787             17     8150000        80.0           2019-01-09      2
# 6223              6     3300000        44.4           2019-03-25      2
# 9349              5     3950000        42.0           2017-03-26      3
# 10730             8     3800000        58.0           2017-10-13      2
# 11239             0     1950000        37.0           2019-03-20      1
# ...

# %% [markdown]
# Общая площадь 25 м2, с потолками 100 метров, явночто-то не так. Эту строчку удалим. Остальные строчки уменьшим в 10 раз.

# %%
data['ceiling_height'] = data['ceiling_height'].replace({20:2.0, 22.6:2.26, 24:2.4, 25:2.5, 26:2.6, 27:2.7, 27.5:2.75, 32:3.2})
data = data[(data['ceiling_height'] <= 10) | (data['ceiling_height'].isna())] # удаляем значения высоты потолков больше 10 м

# %% [markdown]
# # Выводы

# %% [markdown]
# В ходе предобработки данных были проделаны след. шаги:
# - удалены строки с пропусками в столбце floors_total
# - заполнены прпоуски living_area, is_apartment, balcony. В последних двух заполнили пропуски значениями False и 0, для приведения столбцов к нужному нам типу.
# - Привели столбцы first_day_exposition к типу date; floors_total, balcony и last_price - к типу "int".
# - Обработали уникальные значения в столбце locality_name. Для уменьшения колиства ошибок в данном столбце желательно создать базу населенных пунктов, жестко регулируемую по названиям, ввод адреса из предложенных.
# - обработали и исправили ошибки в столбце ceiling_height были ошибки в указании высоты потолков. Причинами могли послужить человеческий фактор и технические ошибки.

# %% [markdown]
# #### check gap

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23610 entries, 0 to 23612
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23610 non-null  int64
#  1   last_price            23610 non-null  int64
#  2   total_area            23610 non-null  float64
#  3   first_day_exposition  23610 non-null  datetime64[ns]
#  4   rooms                 23610 non-null  int64
#  5   ceiling_height        14492 non-null  float64
#  6   floors_total          23610 non-null  int64
#  7   living_area           21740 non-null  float64
#  8   floor                 23610 non-null  int64
#  9   is_apartment          23610 non-null  bool
#  10  studio                23610 non-null  bool
#  11  open_plan             23610 non-null  bool
#  12  kitchen_area          21380 non-null  float64
#  13  balcony               23610 non-null  int64
#  14  locality_name         23562 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_94fc0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_94fc0_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_94fc0_row0_col0" class="data row0 col0" >23,610.00</td>
#                         <td id="T_94fc0_row0_col1" class="data row0 col1" >23,610.00</td>
# ...

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#         'rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floors_total'
#
# стоит учесть наличие пропусков при фильтрации данных

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента В2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> 'ceiling_height' поправил выше, исправления ошибок осталось тем же. Не понимаю, как написать формулу для удаления по условию <, потому что сразу теряется часть данных из-за прпоущенных значений.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />оставил пример в бонусной части

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выполнения пункта 2.4. существует два подхода
#
# Можно механически бороться с выбросами, ...
#
# основная проблема такого подхода — не учитывается неоднородность нашей выборки: у нас здесь и малые поселки, и вторая столица страны, и исторический фонд и массовая застройка, и однушки и довольно большое кол-во многокомнатных квартир, или наоборот одна две квартиры с количеством комнат больше 7-ми ...
#
#
#
# если бы у нас в таблице были бы только однокомнатные квартиры из определенного района массовой застройки, тогда да, мы бы боролись с выбросами традиционными способами, при нашем многообразии населенных пунктов, многокомнатности такие подходы не работают... т.е. они работают, но это усложнит наш проект — придется разбить и объединить записи нашей таблицы по нескольким параметрам (кол-во комнат, район, и т.д.), а затем только выполнять все остальные пункты на каждой отдельной выборке
#
# Остается другой подход — убираем редкие значения и следим за количеством потерь...
#
# Для выборки из 23-х тысяч значений, несколько записей со стоимостью квадратного метра выше 1-го млн. руб., довольно редкое явление
#
# Хороший пример, высота потолков, которую мы отрезаем по нижней и верхней планке, это скорее аномальные записи, посмотрим на другой аспект — на редкости: кол-во комнат
#
# __т.е. мы не говорим о том, что квартир с кол-ом комнат выше 7 не бывает, мы говорим, что для нашего исследования это редкие выбивающиеся из общей картины уникальные объекты, по которым необходимо проводить отдельную работу ...__
#
# подобным образом рассматриваем и остальные параметры
#
# наши помощники
#
# 1. гистограммы, с хорошим масштабом
# 2. метод describe() или облегченная версия, пример выше
# 3. метод value_counts()
#
# плюс жизненный опыт

# %%
# check
data.rooms.value_counts().to_frame()
# Out:
#     rooms
# 1    8013
# 2    7912
# 3    5795
# 4    1177
# 5     325
# 0     194
# 6     104
# 7      59
# 8      12
# 9       8
# 10      3
# 11      2
# 14      2
# 19      1
# 16      1
# 12      1
# 15      1

# %% [markdown]
# Будем считать, что выбивающиеся значения - больше 10 комнат, таких объектов совсем не много. Объекты, где больше 10 комнат - удаляем.

# %%
data= data[data['rooms'] <= 10]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23602 entries, 0 to 23612
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23602 non-null  int64
#  1   last_price            23602 non-null  int64
#  2   total_area            23602 non-null  float64
#  3   first_day_exposition  23602 non-null  datetime64[ns]
#  4   rooms                 23602 non-null  int64
#  5   ceiling_height        14486 non-null  float64
#  6   floors_total          23602 non-null  int64
#  7   living_area           21732 non-null  float64
#  8   floor                 23602 non-null  int64
#  9   is_apartment          23602 non-null  bool
#  10  studio                23602 non-null  bool
#  11  open_plan             23602 non-null  bool
#  12  kitchen_area          21372 non-null  float64
#  13  balcony               23602 non-null  int64
#  14  locality_name         23554 non-null  object
# ...

# %%
# check
data.total_area.hist(bins = 150, figsize = (15,3));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры менее 20-ти и более 250-ти квадратных метров можно считать редкостями

# %%
# check
data.total_area.hist(bins = 150, figsize = (15,3), range = (180,500));

# %%
# check
data.total_area.hist(bins = 15, figsize = (15,3), range = (180,500));

# %%
# check
data.total_area.hist(bins = 15, figsize = (15,3), range = (0,25));

# %%
# удаляем выбивающиеся значения столбца "total_area"
data = data[(data['total_area'] >= 20) & (data['total_area'] <= 250)]
data.total_area.hist(bins = 15, figsize = (15,3), range = (0,300));
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23469 entries, 0 to 23612
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23469 non-null  int64
#  1   last_price            23469 non-null  int64
#  2   total_area            23469 non-null  float64
#  3   first_day_exposition  23469 non-null  datetime64[ns]
#  4   rooms                 23469 non-null  int64
#  5   ceiling_height        14401 non-null  float64
#  6   floors_total          23469 non-null  int64
#  7   living_area           21626 non-null  float64
#  8   floor                 23469 non-null  int64
#  9   is_apartment          23469 non-null  bool
#  10  studio                23469 non-null  bool
#  11  open_plan             23469 non-null  bool
#  12  kitchen_area          21279 non-null  float64
#  13  balcony               23469 non-null  int64
#  14  locality_name         23421 non-null  object
# ...

# %% [markdown]
# # days_exposition

# %%
data['days_exposition'].hist(bins=50, figsize=(15,3));

# %%
data['days_exposition'].hist(bins=50, range=(0, 10), figsize=(15,3));

# %%
data['days_exposition'].hist(bins=150, range=(400, 1600), figsize=(15,3));

# %%
# Будем считать аномалиями значения больше 1400, их убираем. 
data.query('days_exposition > 1400')['days_exposition'].count()
# Out:
# 19

# %%
data = data[(data['days_exposition'] > 2 ) & (data['days_exposition'] <= 1400) | (data['days_exposition'].isna())]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23446 entries, 0 to 23612
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23446 non-null  int64
#  1   last_price            23446 non-null  int64
#  2   total_area            23446 non-null  float64
#  3   first_day_exposition  23446 non-null  datetime64[ns]
#  4   rooms                 23446 non-null  int64
#  5   ceiling_height        14384 non-null  float64
#  6   floors_total          23446 non-null  int64
#  7   living_area           21605 non-null  float64
#  8   floor                 23446 non-null  int64
#  9   is_apartment          23446 non-null  bool
#  10  studio                23446 non-null  bool
#  11  open_plan             23446 non-null  bool
#  12  kitchen_area          21258 non-null  float64
#  13  balcony               23446 non-null  int64
#  14  locality_name         23398 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента В2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не понимаю, как написать код для удаления из ДФ строк. Потому что там есть прпоущенные значения и эти данные тоже теряются.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />пример оставил в бонусной части

# %% [markdown]
# # last_price

# %%
data['last_price'].hist(bins=200, figsize=(15,3));

# %%
data['last_price'].hist(bins=150, range=(20000000, 80000000), figsize=(15,3));

# %%
data.query('last_price > 25000000').count()
# Out:
# total_images            363
# last_price              363
# total_area              363
# first_day_exposition    363
# rooms                   363
# ceiling_height          245
# floors_total            363
# living_area             321
# floor                   363
# is_apartment            363
# studio                  363
# open_plan               363
# kitchen_area            327
# balcony                 363
# locality_name           363
# airports_nearest        350
# cityCenters_nearest     353
# parks_around3000        353
# parks_nearest           266
# ponds_around3000        353
# ponds_nearest           272
# days_exposition         260
# dtype: int64

# %% [markdown]
# Значения более 25 млн. руб. убираю. Т.к. возможно там и будут ошибки, вызванные человеческим фактором (ошиблись количеством нулей), но кол-во потерянных данных не так велико.

# %%
data = data[(data['last_price'] <=25000000) | (data['last_price'].isna())]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23083 entries, 0 to 23612
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23083 non-null  int64
#  1   last_price            23083 non-null  int64
#  2   total_area            23083 non-null  float64
#  3   first_day_exposition  23083 non-null  datetime64[ns]
#  4   rooms                 23083 non-null  int64
#  5   ceiling_height        14139 non-null  float64
#  6   floors_total          23083 non-null  int64
#  7   living_area           21284 non-null  float64
#  8   floor                 23083 non-null  int64
#  9   is_apartment          23083 non-null  bool
#  10  studio                23083 non-null  bool
#  11  open_plan             23083 non-null  bool
#  12  kitchen_area          20931 non-null  float64
#  13  balcony               23083 non-null  int64
#  14  locality_name         23035 non-null  object
# ...

# %% [markdown]
# # living_area

# %%
data['living_area'].hist(bins=150, figsize=(15,3));

# %%
data['living_area'].hist(bins=10, range=(0,50), figsize=(15,3));

# %%
data['living_area'].hist(bins=100, range=(75,150), figsize=(15,3));

# %% [markdown]
# Считаю, что значения больше 105 - редкости, как и значения меньше 10.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента В2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Тоже самое, не могу понять, как написать код

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />пример оставил в бонусной части

# %%
# избавляемся от редких значений
data = data[(data['living_area'] >= 10) & (data['living_area'] <= 105) | (data['living_area'].isna())]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22931 entries, 0 to 23612
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22931 non-null  int64
#  1   last_price            22931 non-null  int64
#  2   total_area            22931 non-null  float64
#  3   first_day_exposition  22931 non-null  datetime64[ns]
#  4   rooms                 22931 non-null  int64
#  5   ceiling_height        14028 non-null  float64
#  6   floors_total          22931 non-null  int64
#  7   living_area           21132 non-null  float64
#  8   floor                 22931 non-null  int64
#  9   is_apartment          22931 non-null  bool
#  10  studio                22931 non-null  bool
#  11  open_plan             22931 non-null  bool
#  12  kitchen_area          20786 non-null  float64
#  13  balcony               22931 non-null  int64
#  14  locality_name         22883 non-null  object
# ...

# %% [markdown]
# # kitchen_area

# %%
data['kitchen_area'].hist(bins=150, figsize=(15,3));

# %%
data['kitchen_area'].hist(bins=50, range=(0,8), figsize=(15,3));

# %%
data['kitchen_area'].hist(bins=100, range=(20,50), figsize=(15,3));

# %% [markdown]
# Предлагаю убрать значения меньше 5 и больше 50 м2.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента В2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Тоже самое, много прпоусков.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />пример оставил в бонусной части

# %%
data = data[(data['kitchen_area'] >= 5) & (data['kitchen_area'] <= 50) | (data['kitchen_area'].isna())]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22817 entries, 0 to 23612
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22817 non-null  int64
#  1   last_price            22817 non-null  int64
#  2   total_area            22817 non-null  float64
#  3   first_day_exposition  22817 non-null  datetime64[ns]
#  4   rooms                 22817 non-null  int64
#  5   ceiling_height        13951 non-null  float64
#  6   floors_total          22817 non-null  int64
#  7   living_area           21020 non-null  float64
#  8   floor                 22817 non-null  int64
#  9   is_apartment          22817 non-null  bool
#  10  studio                22817 non-null  bool
#  11  open_plan             22817 non-null  bool
#  12  kitchen_area          20672 non-null  float64
#  13  balcony               22817 non-null  int64
#  14  locality_name         22769 non-null  object
# ...

# %% [markdown]
# # floors_total

# %%
data['floors_total'].hist(bins=150, figsize=(15,3));

# %%
data['floors_total'].hist(bins=50, range=(20,60), figsize=(15,3));

# %% [markdown]
# Больше 27 этайжей - убираем

# %%
data = data[(data['floors_total'] <= 27) | (data['floors_total'].isna())]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22763 entries, 0 to 23612
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22763 non-null  int64
#  1   last_price            22763 non-null  int64
#  2   total_area            22763 non-null  float64
#  3   first_day_exposition  22763 non-null  datetime64[ns]
#  4   rooms                 22763 non-null  int64
#  5   ceiling_height        13927 non-null  float64
#  6   floors_total          22763 non-null  int64
#  7   living_area           20968 non-null  float64
#  8   floor                 22763 non-null  int64
#  9   is_apartment          22763 non-null  bool
#  10  studio                22763 non-null  bool
#  11  open_plan             22763 non-null  bool
#  12  kitchen_area          20622 non-null  float64
#  13  balcony               22763 non-null  int64
#  14  locality_name         22715 non-null  object
# ...

# %% [markdown]
# После обработки редких значений и аномалий потеряли порядка 6% данных, приемлемый результат.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось выполнить пункт 2.4 из брифа проекта
#
# 2.4.	Найдите и устраните редкие и выбивающиеся значения.
#
# __Критичный уровень потерь записей на этапе предобработки составляет 10%, оптимальный 5%__

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.0012, 0.01, .5, .99, .9988]) # выбираем размах в 0,9976 квантилей 
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_0faf5_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0faf5_level0_row0" class="row_heading level0 row0" >0.0012</th>
#                         <td id="T_0faf5_row0_col0" class="data row0 col0" >0.00</td>
#                         <td id="T_0faf5_row0_col1" class="data row0 col1" >21.90</td>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Квантили что это такое
#
# https://fin-accounting.ru/cfa/l1/quantitative/cfa-quartiles-quintiles-deciles-percentiles?ysclid=l7gy2kky4i156375632
#
# они помогают увидеть редкости и аномалии в данных

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_e1b84_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e1b84_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_e1b84_row0_col0" class="data row0 col0" >22,763.00</td>
#                         <td id="T_e1b84_row0_col1" class="data row0 col1" >22,763.00</td>
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Выполнен достойный объем работы
#
# остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#         'ceiling_height', 'last_price'
#
# 8-миметровые потолки или однометровые ... квартира за 12 тыс. руб.

# %% [markdown]
#  <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#         'rooms', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floors_total'
#
# стоит посмотреть на минимальные и максимальные значения колонок
#
# стоит учесть наличие пропусков при фильтрации данных

# %%
# check
data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5));

data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5))
plt.ylim(0, 40);

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# Добавим в  датафрейм и расчитаем след. столбцы:
# - цена одного квадратного метра - price_m2;
# - день недели публикации объявления (0 — понедельник, 1 — вторник и так далее) - num_day;
# - месяц публикации объявления - num_month;
# - год публикации объявления - num_year;
# - тип этажа квартиры (значения — «первый», «последний», «другой») - floors_type;
# - расстояние до центра города в километрах - cityCenters_nearest_km.

# %%
data['price_m2'] = data['last_price'] / data['total_area']

data['num_day'] = pd.DatetimeIndex(data['first_day_exposition']).weekday
data['num_month'] = pd.DatetimeIndex(data['first_day_exposition']).month
data['num_year'] = pd.DatetimeIndex(data['first_day_exposition']).year

data['city_centers_nearest_km'] = data['cityCenters_nearest'] / 1000
data['city_centers_nearest_km'] = data['city_centers_nearest_km'].fillna(100000)
data['city_centers_nearest_km'] = data['city_centers_nearest_km'].astype('int')

def type_floors(data):
    if data['floor'] == 1:
        return 'первый'
    if data['floor'] == data['floors_total']:
        return 'последний'
    return 'другой'
data['floors_type'] = data.apply(type_floors, axis=1)
display(data.head())
data.info()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 4             2    10000000       100.0           2018-06-19      2
# 5            10     2890000        30.4           2018-09-10      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1             NaN            11         18.6      1         False  ...
# 2             NaN             5         34.3      4         False  ...
# 4            3.03            14         32.0     13         False  ...
# 5             NaN            12         14.4      5         False  ...
#
#    parks_nearest  ponds_around3000  ponds_nearest  days_exposition  \
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Функция хорошая, стоит учесть крайние условия: нулевые и отрицательные значения

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит откорректировать расчет
#
#         data['price_m2'] = data['last_price'] / data['living_area']
#
# Стоимость кв. метра рассчитывается от общей площади

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит выполнить пункт проекта
#
#         data['city_centers_nearest_km'] = data['cityCenters_nearest'] / 1000
#
# •	расстояние до центра города в километрах (переведите из м в км и __округлите до целых значений__).

# %% [markdown]
# # Выводы

# %% [markdown]
# В данном шаге добавили и расчитали требуемые столбцы.

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Построим гистограммы требующихся объектов.

# %% [markdown]
# Общая площадь

# %%
print(data['total_area'].describe())
data['total_area'].hist(bins=100, range=(12, 400), figsize=(15,4));
# Out:
# count    22763.000000
# mean        56.813223
# std         23.876797
# min         20.000000
# 25%         40.000000
# 50%         51.000000
# 75%         67.600000
# max        250.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Внешне график похож на распределение Пуассона. Есть незначительное кол-во объектов площадью  более  200м2 (возможно элитная недвижимость, в дальнейшем можно проверить данные показатели, может  даже выделить в отдельную группу для исследования). Пик объявлений приходится на квартиры ~ 45 м2.

# %%
print(data['living_area'].describe())
data['living_area'].hist(bins=150, range=(2, 409), figsize=(15,4));
# Out:
# count    20968.000000
# mean        32.411913
# std         15.532041
# min         10.000000
# 25%         18.500000
# 50%         30.000000
# 75%         41.600000
# max        105.000000
# Name: living_area, dtype: float64

# %% [markdown]
# Сомнительно большое количсетво объектов с площадью ~ 20 - 30 м2, в сравнении с показателями  общей площади - большие разрывы. Так пик значений  общей площади был 40-50м2.

# %%
data.query(
    '15 < living_area < 30' and '40 < total_area').pivot_table(
    index='total_area',  values='living_area', aggfunc='count').hist(bins=100, figsize=(15,4));

# %% [markdown]
# Действительно большое количество объектов с  разрывами между общей и жилой площадью объектов в диапазоне 15-30 м2. Также есть аномальные значения, где разрывы достигают 100-400 м2. Что это может быть? Производственные помещения с комнаткой для персонала? В любом случае разрывы большие и требуют более детального анализа между двумя показателями.

# %%
print(data['kitchen_area'].describe())
data['kitchen_area'].hist(bins=100, range=(1, 112), figsize=(15,4));
# Out:
# count    20622.000000
# mean        10.162556
# std          4.721769
# min          5.000000
# 25%          7.000000
# 50%          9.000000
# 75%         11.600000
# max         50.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Преобладает количество  объектов с площадью кухни 9 м2 (соответствует средней). Есть аномалии более 40 м2, но их количество не значительно.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Хорошие графики, можно изменить размер у графиков (увеличить ширину)
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://pyprog.pro/mpl/mpl_axis_signatures.html) и [там](https://pyprog.pro/mpl/mpl_title.html), и
#
# [тут](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %%
print(data['last_price'].describe())
data['last_price'].hist(bins=100, range=(0, 70000000), figsize=(15,4));
# Out:
# count    2.276300e+04
# mean     5.528330e+06
# std      3.516468e+06
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.590000e+06
# 75%      6.500000e+06
# max      2.500000e+07
# Name: last_price, dtype: float64

# %% [markdown]
# Внешне график соответствует номральному распределению. Пик цены приходитсмя на 5-6 млн. руб. что кажется нормальным. Есть выбивающиеся значения, возможно это объекты с большой площадью, отсюда и логично высокая цена, но таких объектов не много.

# %%
data['rooms'].hist(bins=20,range=(0, 10), figsize=(15,4));

# %% [markdown]
# Преобладают однокомнатные квартиры и 2-3 - х комнатные квартиры. Аномалии с кол-вом квартир - 0 нужно проверять.

# %%
print(data['ceiling_height'].describe())
data['ceiling_height'].hist(bins=10, range=(0, 14), figsize=(15,4));
# Out:
# count    13927.000000
# mean         2.712000
# std          0.271765
# min          1.000000
# 25%          2.500000
# 50%          2.650000
# 75%          2.800000
# max          8.300000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Высота потолков ниже 2 метров кажется не естественной.В  остальном - все хорошо.

# %%
print(data['floor'].describe())
data['floor'].hist(bins=100, range=(1, 33), figsize=(15,4));
# Out:
# count    22763.000000
# mean         5.875500
# std          4.857522
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         27.000000
# Name: floor, dtype: float64

# %% [markdown]
# На данном графике нормальное распределение Пуассона. Небольшое кол-во объектов с кол-вом этажей больше 20.

# %%
data['floors_type'].hist(bins=100, range=(0, 3), figsize=(15,4));

# %% [markdown]
# В основном в объявлениях объекты не на первом и последнем этажах.

# %%
print(data['floors_total'].describe())
data['floors_total'].hist(bins=100, range=(1, 60), figsize=(15,4));
# Out:
# count    22763.000000
# mean        10.713878
# std          6.540948
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         27.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# В данных преобладают 5-ти и 9-ти этажные здания.  Здесь все кажется естественным. Есть  аномалии выше 30-ти этажей, скорее всего  это высокоэтажные здания.

# %%
print(data['cityCenters_nearest'].describe())
data.loc[
    data['cityCenters_nearest'] != data['cityCenters_nearest'].isna(),
    'cityCenters_nearest'].hist(bins=100, range=(181, 65968), figsize=(15,4));
# Out:
# count    17318.000000
# mean     14439.308638
# std       8552.316690
# min        208.000000
# 25%       9763.750000
# 50%      13245.000000
# 75%      16397.500000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# Здесь тоже все кажется естественным. Не забываем, что не мало данных было пропущено.

# %%
print(data['airports_nearest'].describe())
data.loc[
    data['airports_nearest'] != data['airports_nearest'].isna(),
    'airports_nearest'].hist(bins=100, range=(0, 84869), figsize=(15,4));
# Out:
# count    17300.000000
# mean     28881.591908
# std      12753.052246
# min          0.000000
# 25%      18420.000000
# 50%      26941.000000
# 75%      37434.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %%
print(data['parks_nearest'].describe())
data.loc[
    data['parks_nearest'] != data['parks_nearest'].isna(),
    'parks_nearest'].hist(bins=100, range=(1, 3190), figsize=(15,4));
# Out:
# count    7551.000000
# mean      494.530791
# std       343.470004
# min         1.000000
# 25%       289.000000
# 50%       456.000000
# 75%       616.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# Нормальное распределение Пуассона.

# %%
data['num_month'].value_counts().reset_index().sort_values('index').plot(x='index', 
                                                                         kind='bar',
                                                                         figsize=(15,4),
                                                                         grid=True,
                                                                         legend=False)
plt.title('месяц  публикации');

# %% [markdown]
# Чаще всего объявления публикуют в феврале, марте и ноября.

# %%
data['num_day'].value_counts().reset_index().sort_values('index').plot(x='index',
                                                                       kind='bar',
                                                                       grid=True,
                                                                       legend=False,
                                                                       figsize=(15,4))
plt.title('день  публикации')
# Out:
# Text(0.5, 1.0, 'день  публикации')

# %% [markdown]
# Наибольшая активность по публикации объявлений с понедельника по четверг.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Интересно, почему февраль (самый короткий месяц) опережает все месяцы — ?__

# %% [markdown]
# #### Скорость продажи квартир

# %%
print(data['days_exposition'].describe())
data['days_exposition'].hist(bins=50, range=(1, 1580), figsize=(15,4));
# Out:
# count    19786.000000
# mean       177.239007
# std        213.811122
# min          3.000000
# 25%         45.000000
# 50%         94.000000
# 75%        226.000000
# max       1396.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# пиковые значения находятся в пределах до 100 дней. Продажи более 600 дней кажутся аномально долгими. Укрупним выборку и посмотрим на значения в пределах до года. Среднее показывает, что в основном продажи проходили за 180 дней.

# %%
data.query('days_exposition < 100')['days_exposition'].hist(bins=100, figsize=(15,4));

# %% [markdown]
# Очевидно, быстрыми можно считать продажи ~ 45 дней. Продажи в первые 2 недели - это хорошо, но это очень быстро. Может снимали объявления по другим причинам, опять же мы этого не знаем.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Скорость продаж квартир рассчитана корректно
#
# __Интересно посмотреть на изменение средней  скорости продаж по годам__

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Не исследованы моды в 'days_exposition' и как они влияют на скорость продажи, подсказка на что смотреть
#
# [Условия размещения объявлений](https://yandex.ru/support/realty/owner/home/add-ads-housing.html)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Для определения быстрых и долгих продаж оптимальнее ориентироваться на 25-тый и 75-тый квантили

# %% [markdown]
# #### Факторы, влияющие на стоимость объекта

# %% [markdown]
# Рассмотрим влияние общей площади на стоимость объекта.

# %%
(
    data.pivot_table(index='total_area',values='last_price')
    .reset_index()
    .plot(
        kind='scatter', x='total_area', y='last_price', figsize=(10,4), legend=False)
);
print('Коэффициент корреляции = ', data['total_area'].corr(data['last_price']))
# Out:
# Коэффициент корреляции =  0.7739644142017333

# %% [markdown]
# Рассмотрим влияние жилой площади на стоимость объекта.

# %%
(
    data.query('20 <= living_area <= 250')
    .pivot_table(index='living_area',values='last_price')
    .reset_index()
    .plot(
        kind='scatter', x='living_area', y='last_price', figsize=(10,4), legend=False)
);
print('Коэффициент корреляции = ', data['living_area'].corr(data['last_price']))
# Out:
# Коэффициент корреляции =  0.656035860289699

# %% [markdown]
# Рассмотрим влияние площади кухни на стоимость объекта.

# %%
(
    data.pivot_table(index='kitchen_area',values='last_price')
    .reset_index()
    .plot(
        kind='scatter', x='kitchen_area', y='last_price', figsize=(10,4), legend=False)
);
print('Коэффициент корреляции = ', data['kitchen_area'].corr(data['last_price']))
# Out:
# Коэффициент корреляции =  0.5955093284086139

# %% [markdown]
# Рассмотрим зависимость стоимости объекта от этажа, на котором расположен объект.

# %%
(
    data.pivot_table(index='floors_type',values='last_price', aggfunc='median').plot(
        kind='barh',
        figsize=(15,5),
        title='Тип этажа объекта',
        legend=False)
);

# %%
per_factors = ['rooms', 'num_month', 'num_year']

for factors in per_factors:
        data.pivot_table(index=factors,values='last_price', aggfunc='median').plot(
            figsize=(15,4),
            title=factors,
            legend=False)
        print(f'Коэффициент корреляции {factors} = ', data[factors].corr(data['last_price']))
# Out:
# Коэффициент корреляции rooms =  0.4829135807319784
# Коэффициент корреляции num_month =  0.0024967156752581108
# Коэффициент корреляции num_year =  -0.02728603491657101

# %% [markdown]
# Посмотрим, с чем связан спад по годам. Проверим количество объявлений за каждый год.

# %%
data.groupby('num_year')['num_year'].hist(bins=6, figsize=(10,4));

# %% [markdown]
# В 2014 году было самое маленькое значение по количеству объявлений, при этом этот год является лидером по ценам на объекты. В то время, как 2017 и 2018 годы являются лидерами по количеству объявлений, при этом в отношении цены объекта по годам - принимают минимальные значения. Проверим, как менялась площадь объектов по годам.

# %%
(
    data.pivot_table(index='num_year',
                     values=['total_area', 'last_price'],
                     aggfunc=['count','mean','median'])
)
# Out:
#               count                     mean                median
#          last_price total_area    last_price total_area last_price total_area
# num_year
# 2014            115        115  8.813741e+06  77.548957    6800000      73.00
# 2015           1101       1101  6.295475e+06  64.009582    5100000      58.30
# 2016           2651       2651  5.518540e+06  58.084794    4450000      52.12
# 2017           7867       7867  5.418123e+06  56.679556    4450000      51.00
# 2018           8262       8262  5.382473e+06  55.558142    4500000      50.00
# 2019           2767       2767  5.844767e+06  55.997286    5000000      51.10

# %% [markdown]
# Зависимость цены от года обусловлена тем, что в 2014 году не большое кол-во объявлений, при этом объекты были с большей площадью, из-за чего и стоимость объекта больше. В 2017 и 2018 гг. наблюдается максимальное количество объявлений, что влияет на среднее и медианное значение показателей цены.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Если смотреть только на изменение цены по годам мы можем сделать некорректный вывод, что цены падали, а на самом деле цена это параметр на который влияет несколько других факторов, по этой причине можно посмотреть на основные из них:
#
# + изменение кол-ва записей — принять решение о достаточности данных для анализа и сравнения (сравнивать 136 объявлений и 8454, а возможно, что они еще и из разных локаций, не совсем корректно)
# + изменение площади, как основного параметра от которого зависит стоимость квартиры, в 2017-2018 гг. на рынок пришел массовый продавец, и средние значения упали ..., а за ней и цена
# + изменение кол-ва поданных объявлений из разных локаций, т.к. есть питерские квартиры, а есть выборгские квартиры и стоят они по разному, и в разные годы могло быть больше квартир из определенной локации
# + полнота периода для анализа, 2014 и 2019 гг. неполные, а у нас есть сезонные колебания цен, например летнее снижение цен
# + изменение доли дорогих категорий в общей выборке (средние этажи)
#
# и т.д.

# %% [markdown]
# Итак зависимость цены от факторов:
# - общая площадь - зависимость есть, и это логично.
# - жилая площадь - зависимость есть, аналогично зависимости от общей площади.
# - площадь кухни - зависимость есть.
# - количество комнат - зависимость есть, это логично. Но также на графике есть всплеск цены на квартиры, где колво комнат 11-13.
# - тип этажа - тип этажа тоже влияет на стоимость квартир. На первых атажах цены ниже, на последних больше, но самые дорогие на этажах типа "другой".
# - день размещения - Наблюдается рост цен на квартиры выставленные во вторник, далее идет спад.
# - месяц размещения - рост цен в апреле, к июню значительный спас, далее снова рост.
# - год размещения - Зависимость цены от года обусловлена тем, что в 2014 году не большое кол-во объявлений, при этом объекты были с большей площадью, из-за чего и стоимость объекта больше. В 2017 и 2018 гг. наблюдается максимальное количество объявлений, что влияет на среднее и медианное значение показателей цены.

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить  вывод об изменении цен по годам, необходимо учесть другие факторы, которые также изменяются с годами: площадь и кол-во объявлений о продаже (стоит добавить или графики, или сводные таблицы и исследовать взаимное влияние параметров)
#
#         год размещения - зависимость есть. Так самые большие цены были в 2014 году, далее длительный спад. Цены пошли вверх только с 2018 года.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />      Стоит поменять тип у первых трех графиков
#
# Шаг 4. Проведите исследовательский анализ данных:
#
# 3.	Какие факторы больше всего влияют на общую (полную) стоимость объекта?
#     Изучите, зависит ли цена от:
#     +	общей площади;
#     +	жилой площади;
#     +	площади кухни;
#     +	количества комнат;
#     +	этажа, на котором расположена квартира (первый, последний, другой);
#     +	даты размещения (день недели, месяц, год).
#
# Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
#
#
#
# Советы по графикам:
#
# + зависимость параметров (от площади, удалённости от центра) оптимальнее рассматривать на точечных графиках (тип scatter),
# + динамику на линейных (это про сравнение цен за год, месяц, день недели), — стоит сгруппировать значения и рассчитать среднее или медианное значение
# + сравнение цен на барах (для сравнение средней стоимости квартиры по трем категориям), — стоит сгруппировать значения и рассчитать среднее или медианное значение

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />  Можно попробовать настроить вид точечных графиков
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)
#
# Примеры расчета коэф. корреляции и не только
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?ysclid=l9ev0utyg728177057)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавить расчет коэффициента корреляции для поиска линейных зависимостей

# %% [markdown]
# #### Средняя цена квадратного метра по населенным пунктам

# %%
price_m2_mean = data.groupby('locality_name')['locality_name'].count().sort_values(ascending=False).head(10)
data.query('locality_name in @price_m2_mean.index')\
.pivot_table(index='locality_name', values='price_m2', aggfunc='mean').sort_values('price_m2',ascending=False)\
.plot(y='price_m2', kind='bar', legend=False)
# Out:
# <AxesSubplot:xlabel='locality_name'>

# %% [markdown]
# - Самая высокая стоимось квадратного метра в Санкт_петербурге.
# - Самая низкая в Выборге.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />      Можно развернуть график
#
#      kind='barh'

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />ТОП-10 рассчитан корректно

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# #### Зависимость стоимости объекта от расстояния до центра города

# %%
(
    data.query('locality_name == "Санкт-Петербург" and city_centers_nearest_km != 100000')  
    .pivot_table(index='city_centers_nearest_km', values='last_price')
    .plot( grid=True, style='o-', xlim=(0, 30), figsize=(10, 5), legend=False,
          title='Зависимость стоимости объекта от расстояния до центра города' )
)
plt.show()

# %% [markdown]
# На графике прослеживается зависимость от расстояния до центра города. Так наиболее дорогие квартиры расположены в диапазоне до 8 км от центра. Есть всплески в районах 20-ти, возможно это элитная недвижимость.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит изучить записи, которые привели к выбросу на 27-м км.

# %%
data.query('locality_name == "Санкт-Петербург" and city_centers_nearest_km == 27')
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 744             13    14350000        74.0           2017-11-28      2
# 5940             6     2250000        32.0           2018-02-27      1
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 744             3.13             5         30.0      3         False  ...
# 5940             NaN             2         16.5      2         False  ...
#
#       parks_nearest  ponds_around3000  ponds_nearest  days_exposition  \
# 744          1496.0               0.0            NaN            128.0
# 5940            NaN               0.0            NaN            178.0
#
#            price_m2  num_day  num_month  num_year  city_centers_nearest_km  \
# 744   193918.918919        1         11      2017                       27
# 5940   70312.500000        1          2      2018                       27
#
#       floors_type
# 744        другой
# 5940    последний
#
# [2 rows x 28 columns]

# %%
data.query('locality_name == "Санкт-Петербург" and 20 < city_centers_nearest_km < 30')\
.pivot_table(index='city_centers_nearest_km', values='last_price')
# Out:
#                            last_price
# city_centers_nearest_km
# 21                       5.081966e+06
# 22                       5.252893e+06
# 23                       4.126867e+06
# 24                       3.862235e+06
# 25                       4.048664e+06
# 26                       3.575000e+06
# 27                       8.300000e+06
# 28                       4.910500e+06
# 29                       3.833333e+06

# %% [markdown]
# К выбросу на 27-м км привела запись объекта стоимостью 14 350 000 руб., которая увеличила среднюю стоимость объектов.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Самое важное, что на 27-м км. всего 2 записи, одна из которыых аномальна ..., кол-во наблюдений важный параметр для оценки качества данных

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит посмотреть на категории квартир, которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре

# %%
data.query('locality_name == "Санкт-Петербург" and city_centers_nearest_km != 100000')['city_centers_nearest_km'].describe()
# Out:
# count    14853.000000
# mean        11.315626
# std          4.711073
# min          0.000000
# 25%          8.000000
# 50%         12.000000
# 75%         15.000000
# max         29.000000
# Name: city_centers_nearest_km, dtype: float64

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Извини не донес на второй итерации
#
# код фильтрации работает некорректно
#
#         data.query('locality_name == "Санкт-Петербург"' and 'city_centers_nearest_km != 100000')
#
# он отбирает все записи из выборки, кроме записей, которые не подходят под условие
#
#         city_centers_nearest_km != 100000
#
# пример ниже, к нам в выборку попали не только питерские квартиры, но и из других городов

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента В3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Понял ошибку, спасибо.

# %%
# check
data.query('locality_name == "Санкт-Петербург" and city_centers_nearest_km != 100000')['locality_name'].unique()
# Out:
# array(['Санкт-Петербург'], dtype=object)

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> код фильтрации работает некорректно
#
#         data.query('locality_name == "Санкт-Петербург"' and 'city_centers_nearest_km != 10000')
#
# он отбирает все записи из выборки, кроме записей, которые не подходят под условие
#
#         city_centers_nearest_km != 10000

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# В результате исследования:
# 1. Провели предобработку данных:
# - удалены строки с пропусками в столбце floors_total
# - заполнены прпоуски living_area, is_apartment, balcony. В последних двух заполнили прпоуски значениями False и 0, для приведения столбцов к нужному нам типу.
# - Привели столбцы first_day_exposition к типу date; floors_total, balcony и last_price - к типу "int".
# - Обработали уникальные значения в столбце locality_name. Для уменьшения колиства ошибок в данном столбце желательно создать базу населенных пунктов, жестко регулируемую по названиям, ввод адреса из предложенных.
# - обработали и исправили ошибки в столбце ceiling_height были ошибки в указании высоты потолков. Причинами могли послужить человеческий фактор и технические ошибки. Также избавились от редкостей и аномалий в остальных столбцах датафрейма.
# 2. Путем вычисления были добавлены след. данные:
# - цена квадратного метра;
# - день недели, месяц и год публикации объявления;
# - этаж квартиры; варианты — первый, последний, другой;
# - расстояние до центра города перевели из метров в километры.
# 3. Провели исследовательский анализ:
# - Скорость продажи квартир:
#  - быстрыми можно считать продажи ~ 45 дней. Продажи в первые 2 недели - это хорошо, но это очень быстро. Может снимали объявления по другим причинам, опять же мы этого не знаем. Продажи более 600 дней кажутся аномально долгими. Среднее показывает, что в основном продажи проходили за 180 дней.
# - Факторы влияющие на стоимость объекта:
#  - общая площадь - зависимость есть, и это логично.
#  - жилая площадь - зависимость есть, аналогично зависимости от общей площади.
#  - площадь кухни - зависимость есть.
#  - количество комнат - зависимость есть, это логично. Но также на графике есть всплеск цены на квартиры, где колво комнат 11-13.
#  - тип этажа - тип этажа тоже влияет на стоимость квартир. На первых атажах цены ниже, на последних больше, но самые дорогие на этажах типа "другой".
#  - день размещения - Наблюдается рост цен на квартиры выставленные во вторник, далее идет спад.
#  - месяц размещения - рост цен в апреле, к июню значительный спас, далее снова рост.
#  - год размещения - Зависимость цены от года обусловлена тем, что в 2014 году не большое кол-во объявлений, при этом объекты были с большей площадью, из-за чего и стоимость объекта больше. В 2017 и 2018 гг. наблюдается максимальное количество объявлений, что влияет на среднее и медианное значение показателей цены.
#
# - Средние цены по 10 наиболее популярным населенным пунктам:
#  - Самая высокая стоимось квадратного метра в Санкт_петербурге.
#  - Самая низкая в Выборге.
# - Зависимость стоимости объекта от удаленности от центра:
#  - Наиболее дорогие квартиры расположены в диапазоне до 8 км от центра. Есть всплески в районе 27 км есть выбросы, возможно это элитная недвижимость. К выбросу на 27-м км привела запись объекта стоимостью 14 350 000 руб., которая увеличила среднюю стоимость объектов на данном отрезке удаленности от центра.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента В3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Надеюсь ничего не прпоустил. Спасибо тебе большое за помощь и подсказки.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Технически вывод хороший, есть сравнения показателей, инсайты, анализ рынка недвижимости, молодец
#
# Осталось перепроверить итоговый вывод после исправления всех комментариев

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнил исследовательскую работу, молодец, показал хороший уровень навыков программирования
#
# Критические ❌ комментарии
#
# + проверить корректность заполнения пропусков синтетическими данными
# + настроить фильтрацию редких значений в п. 2.4
# + добавить вывод в п. 4.3
# + подправить графики в п. 4.3 и добавить расчет коэф. корреляции для поиска линейной зависимости
# + перепроверить график в п.4.5
# + исследовать аномалии в п.4.5
# + поправить итоговый вывод
#
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)
#
# <p> Доп. материал: методы группировки и расчета суммы, средних и т.д.
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
#  Интересная функция в библиотеке пандаса
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)
#
# [Как выбрать определенные столбцы из DataFrame](https://dfedorov.spb.ru/pandas/03.%20%D0%9A%D0%B0%D0%BA%20%D0%B2%D1%8B%D0%B1%D1%80%D0%B0%D1%82%D1%8C%20%D0%BF%D0%BE%D0%B4%D0%BC%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2%D0%BE%20%D0%B8%D0%B7%20DataFrame_.html?ysclid=l9sps5lt6g576766938)
#
# [How to visualise data using histograms in Pandas](https://practicaldatascience.co.uk/data-science/how-to-visualise-data-using-histograms-in-pandas)

# %% [markdown]
# ### Бонус

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />Диаграмма рассеяния

# %%
# check
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# check
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']])
plt.gcf().set_size_inches(12,12);

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена трешки')


data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='living_area', alpha=0.5, figsize=(15,8), c = 'r', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');

# %%
# check
price_pivot_area = data.pivot_table(index='last_price', values=([
    'total_area', 'living_area', 'kitchen_area']), aggfunc='median')
price_pivot_area = price_pivot_area.reset_index()
# Посмотрим на диаграммы рассеяния для столбцов 'total_area', 'living_area', 'kitchen_area'.
for row in ['total_area', 'living_area', 'kitchen_area']:
    sns.relplot(data=price_pivot_area, x='last_price', y=row, kind='scatter')

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='living_area' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'g', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — Жилая');

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Заполнение пропусков синтетическими данными во всей красе (почти сплошная прямая линия посередине облака), стоит или изменить алгоритм, или оставить пропуски, или заполнить пропуски маркерами

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# На примере ниже я покажу как фильтровать записи с пропусками
#
#
# Мягкие условия для удаления через логическую операцию или: оставляем все пропуски или все значения, которые ближе чем 60 000 метров
#
#         df_isna = df_check.query('airports_nearest.isna() | airports_nearest < 60000')
#
# В изначальном датасете было всего записей — 23699 entries, из них заполненные
#
#             15  airports_nearest      18157 non-null  float64
#
# Осталось — 23525 entries, из них заполненные
#
#             15  airports_nearest      17983 non-null  float64
#
# т.е. все пропуски в столбце airports_nearest остались на месте
#
# Знак | обозначает логическую операцию «или», иногда мы ее записываем при помощи оператора «or»

# %%
# check
df_check = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') 
df_check.info()
df_isna = df_check.query('airports_nearest.isna() | airports_nearest < 60000')
df_isna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пример второго варианта фильтрации колонок с пропусками, в обновленной версии библиотеки пандас первый вариант работать, возможно, не будет

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента В3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Вроде понял, делал с оператором &  и не получалось.

# %%
# check
df_check = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') 
df_check.info()
df_isna = df_check[(df_check ['airports_nearest'] < 60000) | (df_check ['airports_nearest'].isna()) ]

df_isna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пример фильтрации колонок с пропусками по промежуткам

# %%
# check
df_check = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') 

df_check = df_check[
                    (
                        (df_check['airports_nearest'] < 70000) | (df_check['airports_nearest'].isna())
                    ) & 
                    (
                        (df_check['airports_nearest'] > 40000) | (df_check['airports_nearest'] < 30000)
                    ) 
                   ]

# %%
df_check['airports_nearest'].hist(bins = 100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
